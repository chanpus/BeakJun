# %% [markdown]
# <a href="https://colab.research.google.com/github/chanpus/BeakJun/blob/main/100jun20230123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q11 잘 몰라서 보고했음. 보니까 이해좀 함.
n= int(input())
a=[0]*n
stack=[]
num=1
result=True
answer=""
for i in range(n):a[i]=int(input())

for i in range(n):
  su=a[i]
  if su>=num:
    while su>=num:
      stack.append(num)
      num+=1
      answer+="+\n"
    stack.pop()
    answer+="-\n"
  else:
    n=stack.pop()
    if n>su:
      print("NO")
      result=False
      break
    else:
      answer+="-\n"

      1
if result:
  print(answer)
# Out:
# 8
# 4
# 3
# 6
# 8
# 7
# 5
# 2
# 1
# +
# +
# +
# +
# -
# +
# +
# +
# -
# +
# +
# -
# +
# +
# +
# +

# %%
#Q15

n=int(input())
A=[]
for i in range(n):A.append(int(input()))

for i in range(n-1):
  for j in range(n-i-1):
    if A[j]>A[j+1]:
      temp=A[j+1]
      A[j+1]=A[j]
      A[j]=temp

for i in range(n):print(A[i])
# Out:
# 4
# 3
# 7
# 4
# 5
# 3
# 4
# 5
# 7
# 3
# 4
# 5
# 7
# 3
# 4
# 5
# 7

# %%
#Q16

n=int(input())
A=[]
for i in range(n):A.append(int(input()))

for i in range(n-1):
  change=False
  for j in range(n-i-1):
    if A[j]>A[j+1]:
      temp=A[j+1]
      A[j+1]=A[j]
      A[j]=temp
      change=True
  if change==False:
    res=i+1
    break

print(res)
# Out:
# 5
# 10
# 1
# 5
# 2
# 3
# [1, 2, 3, 5, 10]
# 3

# %%
#Q17

A=list((input()))

res=""
for i in range(len(A)):
  A[i]=int(A[i])

for i in range(len(A)):
  MAX=i
  for j in range(i, len(A)):
    if A[MAX]<A[j]:MAX=j
  temp=A[i]
  A[i]=A[MAX]
  A[MAX]=temp
  

for i in range(len(A)):res += str(A[i])

print(res)
# Out:
# 23561
# [6, 3, 5, 2, 1]
# [6, 5, 3, 2, 1]
# [6, 5, 3, 2, 1]
# [6, 5, 3, 2, 1]
# [6, 5, 3, 2, 1]
# 65321

# %%
#Q12

n=int(input())
A=list(map(int,input().split()))
B=[-1]*n
stack=[]

for i in range(n):
  
  #if len(stack)==0 or (A[i]<stack[-1]):
    #stack.append(i)

  #print(A[i])
  #print(stack[-1])

  if stack and A[i]>A[stack[-1]]:
      while stack and A[stack[-1]] < A[i]:
        B[stack.pop()]=A[i]
  stack.append(i)
  #for i in range(n):
    #print(A[B[i]], end=" ")
  #print("\n")
  #print(stack)

for i in range(n):
  print(B[i], end=" ")
# Out:
# 4
# 3 5 2 7
# 5 7 7 -1

# %%
#Q13

from collections import deque

dq=deque()
N = int(input())
for i in range(N):dq.appendleft(i+1)

while(1):
  if len(dq)==1:break
  dq.pop()
  if len(dq)==1:break
  temp=dq.pop()
  dq.appendleft(temp)

print(dq[0])
# Out:
# 6
# deque([6, 5, 4, 3, 2, 1])
# deque([6, 5, 4, 3, 2])
# deque([2, 6, 5, 4, 3])
# deque([2, 6, 5, 4])
# deque([4, 2, 6, 5])
# deque([4, 2, 6])
# deque([6, 4, 2])
# deque([6, 4])
# deque([4, 6])
# deque([4])
# 4

# %%
#Q18

n=int(input())
li=list(map(int,input()))

for i in range(n):
